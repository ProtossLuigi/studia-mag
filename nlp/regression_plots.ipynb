# %%
import json
import matplotlib.pyplot as plt

# %%
with open('learning_metrics.json', 'r') as f:
    metrics = json.load(f)
with open('learning_metrics2.json', 'r') as f:
    metrics2 = json.load(f)
metrics.update(metrics2)

# %%
metrics

# %%
x = list(range(50))
plt.plot(x, list(map(float, metrics['full_m1.bin']['train']['r2'])), label='full_m1')
plt.plot(x, list(map(float, metrics['full_m2.bin']['train']['r2'])), label='full_m2')
plt.plot(x, list(map(float, metrics['sample_m1.bin']['train']['r2'])), label='sample_m1')
plt.plot(x, list(map(float, metrics['sample_m2.bin']['train']['r2'])), label='sample_m2')
plt.legend()

# %%
x = list(range(50))
plt.plot(x, list(map(float, metrics['full_m1.bin']['train']['mse'])), label='full_m1')
plt.plot(x, list(map(float, metrics['full_m2.bin']['train']['mse'])), label='full_m2')
plt.plot(x, list(map(float, metrics['sample_m1.bin']['train']['mse'])), label='sample_m1')
#plt.plot(x, list(map(float, metrics['sample_m2.bin']['train']['mse'])), label='sample_m2')
plt.legend()

# %%
x = list(range(50))
plt.plot(x, list(map(float, metrics['full_m1.bin']['train']['mse'])), label='full_m1')
plt.legend()

# %%
x = list(range(50))
plt.plot(x, list(map(float, metrics['full_m2.bin']['train']['mse'])), label='full_m2')
plt.legend()

# %%
x = list(range(50))
plt.plot(x, list(map(float, metrics['sample_m1.bin']['train']['mse'])), label='sample_m1')
plt.legend()

# %%
x = list(range(50))
plt.plot(x, list(map(float, metrics['sample_m2.bin']['train']['mse'])), label='sample_m2')
plt.legend()

# %%
x = list(range(50))
plt.plot(x, list(map(float, metrics['full_m1.bin']['val']['r2'])), label='full_m1')
plt.plot(x, list(map(float, metrics['full_m2.bin']['val']['r2'])), label='full_m2')
plt.plot(x, list(map(float, metrics['sample_m1.bin']['val']['r2'])), label='sample_m1')
plt.plot(x, list(map(float, metrics['sample_m2.bin']['val']['r2'])), label='sample_m2')
plt.legend()

# %%
x = list(range(50))
plt.plot(x, list(map(float, metrics['full_m1.bin']['val']['mse'])), label='full_m1')
plt.legend()

# %%
x = list(range(50))
plt.plot(x, list(map(float, metrics['full_m2.bin']['val']['mse'])), label='full_m2')
plt.legend()

# %%
x = list(range(50))
plt.plot(x, list(map(float, metrics['sample_m1.bin']['val']['mse'])), label='sample_m1')
plt.legend()

# %%
x = list(range(50))
plt.plot(x, list(map(float, metrics['sample_m2.bin']['val']['mse'])), label='sample_m2')
plt.legend()

# %%
x = list(range(50))
plt.plot(x, list(map(float, metrics['full_m1.bin']['val']['mse'])), label='full_m1')
plt.plot(x, list(map(float, metrics['full_m2.bin']['val']['mse'])), label='full_m2')
plt.plot(x, list(map(float, metrics['sample_m1.bin']['val']['mse'])), label='sample_m1')
#plt.plot(x, list(map(float, metrics['sample_m2.bin']['val']['mse'])), label='sample_m2')
plt.legend()

# %%
x = list(range(50))
# plt.plot(x, list(map(float, metrics['full_m1.bin']['val']['mse'])), label='full_m1')
# plt.plot(x, list(map(float, metrics['full_m2.bin']['val']['mse'])), label='full_m2')
# plt.plot(x, list(map(float, metrics['sample_m1.bin']['val']['mse'])), label='sample_m1')
plt.plot(x, list(map(float, metrics['sample_m2.bin']['val']['mse'])), label='sample_m2')
plt.legend()
